# %%
import pandas as pd
import numpy as np
import os

# %%
#Importing orders combined pickle format
orders_products_combined = pd.read_pickle(r"C:\Users\user\Desktop\Data Analytics\02-12-2023 Instacart Basket Analysis\02 Data\Prepared data\orders_products_combined.pkl")

# %% [markdown]
# ### Merging

# %%
#Checking the shape
orders_products_combined.shape
# Out:
# (32434489, 10)

# %%
#Checking output
orders_products_combined.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  hour_of_day  \
# 0   2539329        1             1                   2            8
# 1   2539329        1             1                   2            8
# 2   2539329        1             1                   2            8
# 3   2539329        1             1                   2            8
# 4   2539329        1             1                   2            8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0               11.114836         196                  1          0   both
# 1               11.114836       14084                  2          0   both
# 2               11.114836       12427                  3          0   both
# 3               11.114836       26088                  4          0   both
# 4               11.114836       26405                  5          0   both

# %%
#Importing products csv
df_prods = pd.read_csv(r"C:\Users\user\Desktop\Data Analytics\02-12-2023 Instacart Basket Analysis\02 Data\Prepared data\products_prepared.csv", index_col = 0)

# %%
#Checking output
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
#Merging
orders_products_merged = orders_products_combined.merge(df_prods, on = 'product_id')

# %%
#Checking output
orders_products_merged.tail()
# Out:
#           order_id  user_id  order_number  orders_day_of_week  hour_of_day  \
# 32404854   1320836   202557            17                   2           15
# 32404855     31526   202557            18                   5           11
# 32404856    758936   203436             1                   2            7
# 32404857   2745165   203436             2                   3            5
# 32404858   3093936   205420             1                   4           14
#
#           days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 32404854                1.000000       43553                  2          1
# 32404855                3.000000       43553                  2          1
# 32404856               11.114836       42338                  4          0
# 32404857               15.000000       42338                 16          1
# 32404858               11.114836       28818                  8          0
#
# ...

# %%
#Confirming that we have a full match
orders_products_merged['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
#Expoting in pickle format due to the size of df
path = r"C:\Users\user\Desktop\Data Analytics\02-12-2023 Instacart Basket Analysis\02 Data"

# %%
orders_products_merged.to_pickle(os.path.join(path,'Prepared Data', 'orders_products_merged.pkl'))
